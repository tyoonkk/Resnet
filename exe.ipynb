# %% [markdown]
# # ResNet

# %% [markdown]
# [Reference] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun (2016) "Deep Residual Learning for Image Recognition", CVPR2016

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd/content/gdrive/MyDrive/Colab Notebooks/머신러닝 4학년/기말고사프로젝트
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/머신러닝 4학년/기말고사프로젝트

# %%
# !python main.py
# Out:
# Namespace(batch_size=128, num_epochs=51, lr=0.001, l2=0.0001, model_name='resnet18', pretrained=None, train='train')
# Files already downloaded and verified
# Files already downloaded and verified
# 네트워크의 연결을 성공하였습니다.
# Datasets을 성공적으로 불러왔습니다.
# 모델 훈련을 시작합니다.
# 100% 51/51 [52:39<00:00, 61.94s/it, train loss=0.114, test loss=0.384]
# /content/gdrive/MyDrive/Colab Notebooks/머신러닝 4학년/기말고사프로젝트/training.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load('./results/' + self.model_name  + '_best.pth'))
# Files already downloaded and verified
# Files already downloaded and verified
# 테스트셋에 대한 데이터는 증강이 없습니다.
# Epoch50: Train Accuracy: 95.444, Test Accuraccy: 89.63

# %%
# !python main.py --train eval --pretrained ./results/resnet18_best.pth
# Out:
# Namespace(batch_size=128, num_epochs=51, lr=0.001, l2=0.0001, model_name='resnet18', pretrained='./results/resnet18_best.pth', train='eval')
# Files already downloaded and verified
# Files already downloaded and verified
# /content/gdrive/MyDrive/Colab Notebooks/머신러닝 4학년/기말고사프로젝트/training.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load(pretrained))
# 사전학습된 모델을 완성하였습니다.
# 네트워크의 연결을 성공하였습니다.
# Datasets을 성공적으로 불러왔습니다.
#  Train Accuracy: 95.75, Test Accuraccy: 89.51
# /content/gdrive/MyDrive/Colab Notebooks/머신러닝 4학년/기말고사프로젝트/tsne.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(pretrained))
